# %% [markdown]
# # Test Symmetric Dirichlet Parametrization using TinyAD

# %%
import os
os.environ['OMP_NUM_THREADS'] = '1'

# %%
import sys, os
sys.path.append('../')
import MeshFEM
import mesh, mesh_energy, py_newton_optimizer, viewer
import tinyad_parametrization
import parametrization, benchmark
import energy

import numpy as np
import time, copy
import param_utils
import helper_funcs

# %%
m = mesh.Mesh('../../../Models/SmallModels/Octo_cut2.off')

# %%
bdry_uv = helper_funcs.getBDdataOnUnitCircle(m)

# %%
# Tutte Initialization
uv_init = parametrization.harmonic(m, bdry_uv)
flip_list = parametrization.getFlips(m, uv_init)
if len(flip_list) > 0:  uv_init = parametrization.harmonic(m, bdry_uv, True)

# %%
save_uv_path = 'test_save_uv'

# %%
benchmark.reset()
uv_opt, obj_history, grad_history, time_history = tinyad_parametrization.symmdsParamTinyAD(m, uv_init, 1000, 0.01, False, save_uv_path)

# %%
bk_dict = benchmark.to_dict()

# %%
bk_dict.keys()

# %%
benchmark.totalTime('Newton Iterations$', d=bk_dict)

# %%
benchmark.totalTime('Hessian Evaluation$', d=bk_dict)

# %%
len(time_history)

# %%
param_viewer = param_utils.ParametrizationViewer(m,uv_opt)
param_viewer.show()
